# %%
import pandas as pd

# %%
df = pd.read_csv("../data/California_Houses.csv")
df.fillna(0, inplace=True)
df
# Out:
#        Median_House_Value  Median_Income  Median_Age  Tot_Rooms  Tot_Bedrooms  \
# 0                452600.0         8.3252          41        880           129
# 1                358500.0         8.3014          21       7099          1106
# 2                352100.0         7.2574          52       1467           190
# 3                341300.0         5.6431          52       1274           235
# 4                342200.0         3.8462          52       1627           280
# ...                   ...            ...         ...        ...           ...
# 20635             78100.0         1.5603          25       1665           374
# 20636             77100.0         2.5568          18        697           150
# 20637             92300.0         1.7000          17       2254           485
# 20638             84700.0         1.8672          18       1860           409
# 20639             89400.0         2.3886          16       2785           616
#
# ...

# %%
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "notebook_connected"

# %%
fig1 = px.scatter(df, x="Distance_to_coast", y="Median_House_Value", color="Households", size="Median_Income")
fig1.update_layout(title="California Housing Prices")
fig1.show()
# Out:
# <div>                            <div id="b8ea3eaf-9232-4d6e-a55c-df39e763d351" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8ea3eaf-9232-4d6e-a55c-df39e763d351")) {                    Plotly.newPlot(                        "b8ea3eaf-9232-4d6e-a55c-df39e763d351",                        [{"hovertemplate":"Distance_to_coast=%{x}<br>Median_House_Value=%{y}<br>Median_Income=%{marker.size}<br>Households=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[126,1138,177,219,259,193,514,647,595,714,402,734,468,174,620,264,331,303,419,275,166,366,478,325,422,119,239,397,473,155,378,441,335,329,536,264,374,403,309,696,395,249,189,198,292,382,304,253,160,352,438,407,720,400,233,220,259,244,304,57,187,23,122,159,133,187,332,147,82,611,127,277
# ...

# %%
fig2 = px.scatter_3d(df, x="Distance_to_coast", y="Median_House_Value", z="Population", color="Households", size="Median_Income")
fig2.update_layout(title="3D Plot")
fig2.show()
# Out:
# <div>                            <div id="3aaaab41-b392-47f0-950d-b9e8c878be33" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3aaaab41-b392-47f0-950d-b9e8c878be33")) {                    Plotly.newPlot(                        "3aaaab41-b392-47f0-950d-b9e8c878be33",                        [{"hovertemplate":"Distance_to_coast=%{x}<br>Median_House_Value=%{y}<br>Population=%{z}<br>Median_Income=%{marker.size}<br>Households=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[126,1138,177,219,259,193,514,647,595,714,402,734,468,174,620,264,331,303,419,275,166,366,478,325,422,119,239,397,473,155,378,441,335,329,536,264,374,403,309,696,395,249,189,198,292,382,304,253,160,352,438,407,720,400,233,220,259,244,304,57,187,23,122,159,133,187,332
# ...

# %%
df_scaled = df[["Median_House_Value", "Median_Income", "Median_Age", "Tot_Rooms", "Tot_Bedrooms", "Population", "Households", "Distance_to_coast"]].copy()

for col in df_scaled.columns:
    df_scaled[col] = (df_scaled[col] - df_scaled[col].min()) / (df_scaled[col].max() - df_scaled[col].min())

df_scaled
# Out:
#        Median_House_Value  Median_Income  Median_Age  Tot_Rooms  Tot_Bedrooms  \
# 0                0.902266       0.539668    0.784314   0.022331      0.019863
# 1                0.708247       0.538027    0.392157   0.180503      0.171477
# 2                0.695051       0.466028    1.000000   0.037260      0.029330
# 3                0.672783       0.354699    1.000000   0.032352      0.036313
# 4                0.674638       0.230776    1.000000   0.041330      0.043296
# ...                   ...            ...         ...        ...           ...
# 20635            0.130105       0.073130    0.470588   0.042296      0.057883
# 20636            0.128043       0.141853    0.333333   0.017676      0.023122
# 20637            0.159383       0.082764    0.313725   0.057277      0.075109
# 20638            0.143713       0.094295    0.333333   0.047256      0.063315
# 20639            0.153403       0.130253    0.294118   0.070782      0.095438
#
# ...
